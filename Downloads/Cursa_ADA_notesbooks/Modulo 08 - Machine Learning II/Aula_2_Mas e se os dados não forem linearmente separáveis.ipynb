# %% [markdown]
# # Aula 12 - SVM
#
# Na aula de hoje, vamos explorar os seguintes tópicos em Python:
#
# - 1) Introdução
# - 2) Classificadores de margem
# - 3) Support Vector Machines
# - 4) Funções de kernel
# - 5) SVM na prática com o sklearn
# - 6) SVM para regressão

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 1) Introdução
#
# Na aula de hoje, falaremos sobre um dos mais interessantes métodos de aprendizagm supervisionada: **SVM** (**S**upport **V**ector **M**achines).
#
# Este método tem uma construção extremamente elegante e robusta, que, apesar de complexa, pode ser entendida em termos geométricos simples. Nesta aula, vamos explorar os principais aspectos desta construção, em uma apresentação mais alto-nível, sem nos preocuparmos demais com os detalhes matemáticos.
#
# Um ponto importantíssimo sobre SVMs, que é o que de fato lhes confere poder tão elevado, é sua **capacidade de produzir uma hipótese simples, a partir de um conjunto de hipóteses complexo**, o que tem consequências diretas na **capacidade de generalização** de modelos SVM: eles são capazes de generalizar muito bem, apesar das hipóteses produzidas parecerem altamente complexas, o que é algo formidável!
#
# Não entraremos nos detalhes matemáticos que justificam e provam os pontos acima. Mas, para quem tiver interesse, quase todo livro-texto de machine learning aborda estas questões. Recomendo, em particular, [este livro](https://www.google.com.br/books/edition/Learning_with_Kernels/7r34DwAAQBAJ?hl=pt-BR&gbpv=1&dq=learning+with+kernels&printsec=frontcover), que detalha extensivamente SVM e métodos relacionados; ou então [este livro](https://cs.nyu.edu/~mohri/mlbook/), que aborda formalmente a teoria de aprendizagem, eventualmente culminando no enorme sucesso de SVMs. Por fim, aproveito também pra recomendar [este curso](https://work.caltech.edu/index.html) do Caltech, onde os tópicos abordados no livro do Mohri são apresentados de maneira clara, direta, e muito ilustrativa. Esta é minha maior recomendação para quem tem interesse em iniciar os estudos em teoria de aprendizagem estatística, e então ter todo o fundamento rigoroso pra entender porque SVMs são tão interessantes!
#
# Agora, vamos iniciar nossa exposição, introduzindo um conceito fundamental para SVMs: a **margem**, e os chamados **classificadores de margem**.

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 2) Classificadores de margem
#
# Considere o seguinte dataset supervisionado de um problema de classificação binário:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/d8d83e07-66d8-47c6-a5e4-4a3e232481e2.PNG width=400>
#
# É visível que os dados são linearmente separáveis. De fato, existem infinitas retas possíveis que separam perfeitamente as duas classes. Alguns exemplos:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/bbf3d0a6-4707-471b-9f19-7290c13e4f23.PNG width=400>
#
# Vamos olhar separadamente para cada um destes três modelos:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/6c0bea51-dda9-400c-bb68-d7396e4fa606.PNG width=900>
#
# Apesar de ambos separarem perfeitamente os dados de treino (erro de treino é nulo!), podemos nos perguntar: qual deles tem potencial de apresentar **melhor generalização?**
#
# Para refletirmos sobre isso, considere que queremos classificar o ponto de teste indicado em preto:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/fbed2deb-bb38-4ef5-8558-99b7aff5c7b7.PNG width=900>
#
# É super razoável que este ponto seja classificado como sendo da classe vermelha, não é mesmo? No entanto, o primeiro classificador irá classificá-lo como pertencente à classe azul.

# %% [markdown]
# Podemos nos perguntar: por que isso acontece?
#
# Intuitivamente, é possível dizer que a fronteira de decisão do primeiro modelo está "**muito próxima**" dos pontos da classe vermelha, não é?
#
# Mas, se estamos avaliando a **fronteira de decisão**, é razoável que nos importemos, na realidade, com a proximidade entre ela **e os "pontos mais externos"** da respectiva classe, não é mesmo? Afinal, intuitivamente, estes são os pontos que exercem maior influência sobre a fornteira de decisão, justo?
#
# É aqui que entra o conceito de **margem**:
#
# > Chamamos de **margem** a **menor distância** entre os pontos de treino e a fronteira de decisão
#
# A seguir, visualizamos as margens associadas a cada um dos três modelos:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/72f191fc-7bc0-4451-923a-ecb939e88111.PNG width=900>

# %% [markdown]
# Dada a definição de margem, fica claro que o terceiro modelo seria nossa melhor opção, pois ele **apresenta maior margem**. De fato, intuitivamente, um classificador que apresenta maior margem, terá melhores chances de generalização!
#
# > Chamamos de **classificador de margem máxima** um classificador **linear** que é construído de modo que a margem seja maximizada.

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# ### Classificador de margem suave
#
# Um classificador de margem suave é obtido com uma modificação extremamente simples com relação ao classificador de margem máxima: a permissão de que **erros de classificação** sejam cometidos na base de treino! Uma possível solução seria algo assim:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/cfacd48d-9713-4bec-9fd7-ea1b4ae380f5.PNG width=400>
#
# Neste caso, temos duas observações incorretas dentro da margem - e está tudo bem, pois dados que estas observações são outliers, não precisamos mos preocupar em ajustar a margem a elas!
#
# Com isso, temos um modelo com um viés um pouco maior, mas com variância bem menor - caminhamos na direção do **sweet spot** de generalização!!

# %% [markdown]
# Note, portanto, que a introdução de uma margem suave pode ser visto como **um procedimento de regularização** aplicado ao classificador de margem! E é exatamente assim que veremos este procedimento quando chegarmos em SVM - um procedimento de regularização!
#
# Um classificador de margem suave é também chamado de **classificador de vetores de suporte (*support vector classifier*)**, sendo que os pontos que "apoiam" a margem são justamente os chamados **vetores de suporte (*support vectors*)**.

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;<br><br>
# <li>Um classificador de margem suave (vetores de suporte) introduz um pouco mais de viés ao permitir erros de treino, mas, com isso, aumenta o potencial de generalização, e pode ser aplicável a dados que não são exatamente linearmente separáveis;
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# Estamos chegando perto das SVMs!
#
# Mas, antes de chegarmos lá, é importante frisarmos um ponto fundamental:
#
# > A **fronteira de decisão** de um classificador de margem suave (de vetores de suporte) é **linear** no espaço de features em que o classificador é treinado, ou seja, a hipótese treinada (isto é, a superfície de decisão) será **um hiperplano** de dimensão $D-1$, onde $D$ é a dimensão do espaço de features
#
# Vamos entender melhor o comentário acima com alguns exemplos:

# %% [markdown]
# ### $D=2$
#
# Se temos uma duas features$(X_1, X_2)$, teremos um **hiperplano $1-$dimensional**, que nada mais é que **uma reta** como fronteira de decisão:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/6ca9b6d4-90fb-4d92-8a73-42ecec09d562.PNG width=400>

# %% [markdown]
# ### $D=3$
#
# Se temos uma três features$(X_1, X_2, X_3)$, teremos um **hiperplano $2-$dimensional**, que nada mais é que **um plano** como fronteira de decisão:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/b91951b3-9256-4a38-abd6-287811332db8.PNG width=400>

# %% [markdown]
# ### $D=1$
#
# Se temos uma única feature $(X)$, teremos um **hiperplano $0-$dimensional**, que nada mais é que **um ponto** como fronteira de decisão:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/000d5eb5-25e7-485b-bf36-6ad944970e27.PNG width=400>

# %% [markdown]
# Para dimensões maiores, $D > 3$, não conseguimos mais visualizar a fronteira de decisão, mas, se qualquer forma, ela será linear (por isso, um hiper**plano**!).
#
# Agora estamos prontos para introduzir as tão aguardadas **Support Vector Machines!**

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;<br><br>
# <li>Um classificador de margem suave (vetores de suporte) introduz um pouco mais de viés ao permitir erros de treino, mas, com isso, aumenta o potencial de generalização, e pode ser aplicável a dados que não são exatamente linearmente separáveis;<br><br>
# <li>A fronteira de decisão de um classificador de margem sempre será linear no espaço de features;
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 3) Support Vector Machines
#
# Imagine que temos o seguinte dataset (com uma única dimensão):
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/e00c77e0-14fb-472f-b9ae-f6af7b229ad5.PNG width=400>
#
# É evidente que este dataset **não é linearmente separável**! Portanto, não conseguimos produzir um classificador de vetores de suporte para este dataset **no espaço de features original**.
#
# Mas, aí entra uma ideia muito interessante: e se nós **levarmos os dados para um ou outro espaço?**
#
# Seria possível que no espaço original os dados não sejam linearmente separáveis, mas **o sejam** em algum outro espaço?
#
# Bom, a priori, vamos tentar algo bem simples... Que tal introduzirmos **uma nova feature** $X_2 = X_1^2$? O que aconteceria neste caso?
#
# De fato, ao **introduzirmos** uma nova feature, estamos fazendo com que **cada observação passe a ser caracterizada por duas features ao invés de uma única**!
#
# Ou seja, nosso espaço de features efetivamente muda de $\mathbb{R}^1$ para $\mathbb{R}^2$! Veja:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/8d5e6199-8a33-45cf-9e4f-c6507024fb36.PNG width=800>
#
# O procedimento que fizemos é chamado de **feature map**, e ele é matematicamente representado pelo mapa (função) $\Phi$.
#
# > Como $\Phi$ leva observações do espaço original ($1$D, uma única feature $X_1$, para vetores do novo espaço ($2$D, duas features, $X_1$ e $X_2$), o denotamos como:
# $$\begin{align*}
# \Phi \ \colon \ & \mathbb{R}^1 \longrightarrow \mathbb{R}^2 \\
# & \vec{x} = X_1 \longmapsto \Phi(\vec{x}) = (X_1, X_2)
# \end{align*}$$
#
# Note que no caso ilustrado acima, temos $X_2 = X_1^2$, isto é, $\Phi(\vec{x}) = (X_1, X_1^2)$.
#
# Então, apesar do nome assustador, o feature map é algo que já estávamos acostumados a fazer, quando usamos o [PolynomialFeatures](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html), lembra? :)

# %% [markdown]
# Um pouco mais de terminologia:
#
# > O "espaço original" é comumente chamado de **espaço de input** (representaremos por $\mathcal{X}$); enquanto o espaço após a aplicação do feature map é chamado de **espaço de features (representaremos por $\mathcal{Z}$)**
#
# <img src=https://miro.medium.com/max/872/1*zWzeMGyCc7KvGD9X8lwlnQ.png width=400>
#
# Também é comum se referir ao espaço de features como **espaço z**, devido à comum notação $\Phi(\vec{x}) \equiv \vec{z}$. Neste caso, teríamos:
#
# $$\begin{align*}
# \Phi \ \colon \ & \mathbb{R}^1 \longrightarrow \mathbb{R}^2 \\
# & \vec{x} = X_1 \longmapsto \Phi(\vec{x}) = \vec{z} = (Z_1, Z_2)
# \end{align*}$$

# %% [markdown]
# Uma vez que temos estas definições, podemos perceber a real utilidade do feature map: **os dados não eram linearmente separáveis no espaço de input, mas passaram a ser no espaço de features!**
#
# Isso é realmente formidável, pois, se temos dados linearmente separáveis, podemos **treinar um classificador de margem suave** no espaço de features!
#
# Isso pode parecer estranho, pois, afinal, gostaríamos de separar os dados no espaço original, não é mesmo?
#
# Na verdade, nosso objetivo é que os dados sejam separados, **não importa em que espaço**! Se conseguirmos encontrar um espaço onde há separabilidade através da aplicação de um feature map, bastaria **aplicar o mesmo feature map** aos dados de treino e de teste, e a separabilidade sempre estará garantida!
#
# Muito legal, não é mesmo?
# ![image.png](attachment:image.png)

# %% [markdown]
# Vamos gerar alguns dados pra ver isto funcionando na prática:

# %%
np.random.seed(42)

data = {'X_1': np.random.normal(0, 1, 20)}

df = pd.DataFrame(data)

df['y'] = df['X_1'].apply(lambda x: 1 if abs(x) > 1.1 else 0)
df
# Out:
#          X_1  y
# 0   0.496714  0
# 1  -0.138264  0
# 2   0.647689  0
# 3   1.523030  1
# 4  -0.234153  0
# 5  -0.234137  0
# 6   1.579213  1
# 7   0.767435  0
# 8  -0.469474  0
# 9   0.542560  0
# 10 -0.463418  0
# 11 -0.465730  0
# 12  0.241962  0
# 13 -1.913280  1
# 14 -1.724918  1
# 15 -0.562288  0
# 16 -1.012831  0
# 17  0.314247  0
# 18 -0.908024  0
# 19 -1.412304  1

# %%
sns.scatterplot(data=df, x='X_1', y=np.zeros(df.shape[0]), hue='y')
# Out:
# <Axes: xlabel='X_1'>

# %%
df['X_2'] = df['X_1']**2

# %%
df
# Out:
#          X_1  y       X_2
# 0   0.496714  0  0.246725
# 1  -0.138264  0  0.019117
# 2   0.647689  0  0.419500
# 3   1.523030  1  2.319620
# 4  -0.234153  0  0.054828
# 5  -0.234137  0  0.054820
# 6   1.579213  1  2.493913
# 7   0.767435  0  0.588956
# 8  -0.469474  0  0.220406
# 9   0.542560  0  0.294371
# 10 -0.463418  0  0.214756
# 11 -0.465730  0  0.216904
# 12  0.241962  0  0.058546
# 13 -1.913280  1  3.660641
# 14 -1.724918  1  2.975342
# 15 -0.562288  0  0.316167
# 16 -1.012831  0  1.025827
# 17  0.314247  0  0.098751
# 18 -0.908024  0  0.824508
# 19 -1.412304  1  1.994602

# %%
sns.scatterplot(data=df, x='X_1', y='X_2', hue='y')
# Out:
# <Axes: xlabel='X_1', ylabel='X_2'>

# %% [markdown]
# E claro, embora tenhamos visto um feature map do tipo $\Phi : \mathbb{R}^1 \rightarrow \mathbb{R}^2$, eles podem assumir as mais diferentes formas! Em geral, podemos definir um feature map genérico como $\Phi : \mathcal{X} \rightarrow \mathcal{Z}$ (de forma concreta, $\Phi : \mathbb{R}^m \rightarrow \mathbb{R}^n$, para $m, n$ dimensões arbitrárias!)
#
# Mais um exemplo, $\Phi : \mathbb{R}^2 \rightarrow \mathbb{R}^3$:
#
# <img src=https://s3-sa-east-1.amazonaws.com/lcpi/105e0718-f938-4d09-919a-b37f79b410f7.PNG width=400>
#
# <img src=https://i.pinimg.com/originals/bc/6b/75/bc6b756f5bf44b54f269b2c076cff162.gif width=400>
#
# Finalmente, agora temos todos os elementos necessários para entender o que são as SVMs:
#
# > Uma **Support Vector Machine** nada mais é que **um classificador de margem suave** treinado **no espaço de features**. Portanto, este classificador pressupõe a aplicação prévia de um **feature map** aos dados no espaço de input.

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;<br><br>
# <li>Um classificador de margem suave (vetores de suporte) introduz um pouco mais de viés ao permitir erros de treino, mas, com isso, aumenta o potencial de generalização, e pode ser aplicável a dados que não são exatamente linearmente separáveis;<br><br>
# <li>A fronteira de decisão de um classificador de margem sempre será linear no espaço de features;<br><br>
# <li>Se os dados não forem linearmente separáveis no espaço original (de input), podemos fazer um feature map para levá-los para um espaço de features onde haja separabilidade linear;
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# Da discussão acima, ficou claro que é justamente o feature map que dá grande poder às SVMs. De fato, a possibilidade de conseguirmos separabilidade linear é algo formidável!
#
# Neste contexto, uma pergunta natural é: como escolher um bom feature map? Formalmente, existem infinitos feature maps possíveis! Como escolher, dentre infinitas opções, exatamente o mapa exato que nos garante separabilidade linear no espaço de features? Embora esta pergunta não seja fácil de responder, existem algumas técnicas para nos ajudar a escolher bons feature maps (vamos discutir sobre isso mais a diante).
#
# Além disso, existe um segundo problema, ainda maior: suponha que queiramos introduzir um kernel que leva os pontos para um espaço de features de altíssima dimensionalidade (algo como $\Phi : \mathbb{R}^2 \mapsto \mathbb{R}^{10000}$).
#
# É de se esperar que este seja um feature map **operacionalmente custoso** de ser calculado, não é mesmo? Imagina, ter que aplicar esta transformação para todos os pontos de treino, e depois de teste! De fato, isso rapidamente se torna computacionalmente impraticável...
#
# Pra solucionar este problema, foi introduzido o uso de **funções de kernel** para capturar um aspecto importante dos feature maps!

# %% [markdown]
# Mas, pra entendermos a importância das funções de kernel, é necessário entendermos uma coisa:
#
# > A hipótese do SVM depende apenas do **produto interno** entre as observações no espaço de features!!
#
# A hipótese é a seguinte:
#
# $$f_{H, \alpha}(\vec{x}) = \text{sign} \left ( \sum_{i=1}^N y_i \alpha_i \langle \Phi(\vec{x}) , \Phi(\vec{x}_i) \rangle + b\right ) $$
#
# Entendo os termos:
#
# - Cada $\vec{x}_i$, $i = 1, 2, \cdots, N$ é uma das $N$ **observações de treino**; e cada $y_i$ é o respectivo target;
# - Cada $\alpha_i$ é um [multiplicador de lagrange](https://en.wikipedia.org/wiki/Lagrange_multiplier). Podemos entendê-los simplesmente como **coeficientes numéricos associados a cada observação de treino**, sendo que $\alpha_i > 0$. Podemos entender estes coeficientes como sendo substitutos ao $\vec{w}$ (uma representação [dual](https://en.wikipedia.org/wiki/Duality_(optimization)) do hiperplano);
# - $\langle \Phi(\vec{x}) , \Phi(\vec{x}_i) \rangle$ é o produto interno entre a observação de teste $\vec{x}$ e cada observação de treino $\vec{x}_i$, **no espaço de features**, ou seja, após a aplicação do feature map!
#
# > **Obs.:** na nossa notação de **espaço z**, poderíamos escrever $\Phi(\vec{x}) = \vec{z}$ e $\Phi(\vec{x}_i) = \vec{z}_i$.
# <br><br>
# No entanto, vamos manter a notação explicita $\Phi(\vec{x})$. Não parece, mas isso na verdade facilitará nossa notação!

# %% [markdown]
# Note que, de fato, apenas o produto interno aparece! E é isso que permite o uso das funções de kernel.

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;<br><br>
# <li>Um classificador de margem suave (vetores de suporte) introduz um pouco mais de viés ao permitir erros de treino, mas, com isso, aumenta o potencial de generalização, e pode ser aplicável a dados que não são exatamente linearmente separáveis;<br><br>
# <li>A fronteira de decisão de um classificador de margem sempre será linear no espaço de features;<br><br>
# <li>Se os dados não forem linearmente separáveis no espaço original (de input), podemos fazer um feature map para levá-los para um espaço de features onde haja separabilidade linear;<br><br>
# <li>A única coisa que importa pro SVM é o produto interno entre as observações no espaço de features;
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 4) Funções de kernel
#
# Uma função de kernel $\kappa$ nada mais é que uma **medida de similaridade** entre dois vetores $\vec{x}$ e $\vec{x}'$ (que no nosso caso, são observações). Definimos como:
#
# $$\boxed{\begin{align*}
# \kappa \ \colon \ & \mathcal{X} \times \mathcal{X} \longrightarrow \mathbb{R} \\
# & (\vec{x}, \vec{x}') \longmapsto \kappa(\vec{x}, \vec{x}')
# \end{align*}}$$
#
# Ou seja, um kernel é uma função que, dadas duas observações $\vec{x}$ e $\vec{x}'$, retorna um número real que caracteriza o quão similar as duas observações são entre si.

# %% [markdown]
# **Ponto fundamental**: uma função de kernel permite que **o produto escalar** entre duas observações seja calculado **no espaço de features**, sem que precisemos **explicitamente levar as observações pro espaço de features**.
#
# Ou seja, conseguimos **evitar** que o feautre map, que costuma ser custoso computacionalmente, seja explicitamente aplicado!
#
# E uma vez que pro SVM apenas o produto interno interessa, podemos usar diretamente a função de kernel, que é muito mais computacionalmente simples que o feature map explícito!
#
# Esse é o chamado **kernel trick**.

# %% [markdown]
# _____________
#
# #### Exemplo de aplicação do kernel trick
#
# Considere que temos $\mathcal{X} = \mathbb{R}^2$, isto é, $\vec{x} = (X_1, X_2)$, um espaço de input de duas dimensões.
#
# Vamos considerar um feature map $\Phi : \mathbb{R}^2 \rightarrow \mathbb{R}^6$, ou seja, teremos $\mathcal{Z} = \mathbb{R}^6$ como espaço de features. Explicitamente, a aplicação do feature map é:
#
# $$\Phi(\vec{x}) = \left(1, X_1^2, X_2^2, \sqrt{2}X_1, \sqrt{2}X_2, \sqrt{2}X_1 X_2 \right )$$
#
# Assim, tomando duas observações genéricas $\vec{x}$ e  $\vec{x}'$, temos:
#
# $$\begin{align*}
# \langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle &= \langle \left(1, X_1^2, X_2^2, \sqrt{2}X_1, \sqrt{2}X_2, \sqrt{2}X_1 X_2 \right ), \left(1, X'^2_1, X'^2_2, \sqrt{2}X'_1, \sqrt{2}X'_2, \sqrt{2}X'_1 X'_2 \right )\rangle =
# \\
# \\
# &= 1 + X_1^2 X'^2_1 + X_2^2 X'^2_2 + \left ( \sqrt{2}X_1 \right) \left ( \sqrt{2}X'_1 \right) + \left ( \sqrt{2}X_2 \right )\left ( \sqrt{2}X'_2  \right )+ \left (\sqrt{2}X_1 X_2 \right )\left (\sqrt{2}X'_1 X'_2 \right )  =
# \\
# \\
# &= 1 + X_1^2 X'^2_1 + X_2^2 X'^2_2 + 2 \left ( X_1 X'_1 + X_2 X'_2 + X_1 X'_1 X_2 X'_2 \right )
# \end{align*}$$
#
# Vamos rearranjar os termos acima da seguinte maneira:
#
# $$\begin{align*}
# \langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle &= 1 + \left ( X_1^2 X'^2_1 + X_2^2 X'^2_2 + 2  X_1 X'_1 X_2 X'_2  \right ) + 2 \left ( X_1 X'_1 + X_2 X'_2\right ) =
# \\
# \\
# &= 1 + \left ( X_1 X'_1 + X_2 X'_2\right )^2 + 2 \left ( X_1 X'_1 + X_2 X'_2\right ) =
# \\
# \\
# &= \Big ( 1 + \left ( X_1 X'_1 + X_2 X'_2 \right ) \Big)^2
# \end{align*}$$
#
# Agora, note que: $\langle \vec{x} , \vec{x}' \rangle = \langle (X_1, X_2), (X'_1, X'_2) \rangle = X_1 X'_1 + X_2 X'_2$, exatamente como aparece no resultado acima! Sendo assim, temos:
#
# $$\langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle = \left ( 1 + \langle \vec{x} , \vec{x}' \rangle \right)^2$$
#
# Ou seja, mostramos que é possível escrever o produto interno entre os vetores **no espaço de features** em termos (do produto interno) dos vetores **no espaço de input!**. Oras, isso é justamente o kernel:
#
# $$ \kappa_\Phi(\vec{x}, \vec{x}') = \left ( 1 + \langle \vec{x} , \vec{x}' \rangle \right)^2 = \langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle$$
#
# Este é o ponto! Fizemos o exemplo a seguir para ver de fato como a utilização do kernel é correspondente ao produto interno das observações no espaço de features! Isto é, de fato, $\kappa_\Phi(\vec{x}, \vec{x}') = \langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle$!
#
# É por isso que dizemos que o kernel nos permite **calcular o produto interno entre dois vetores no espaço de features** sem explicitamente "**ter que visitar**" o espaço de features! Este é o ganho de eficiência que os kernels proporcionam!
# _____________

# %% [markdown]
# Assim, definimos **o produto interno no espaço de features** como sendo as medidas de similaridade entre os pontos neste espaço:
#
# $$ \kappa_\Phi(\vec{x}, \vec{x}') = \langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle \ ,$$
#
# E a hipótese é reescrita como:
#
# $$\boxed{f_{H, \alpha}(\vec{x}) = \text{sign} \left ( \sum_{i=1}^N y_i \alpha_i\kappa_\Phi(\vec{x}, \vec{x}_i) + b\right )} $$

# %% [markdown]
# <div class="warning" style='padding:0.1em; background-color:#E9D8FD; color:#69337A'>
# <span>
# <h2>Conclusões</h2>
# <ul>
# <li>Um classificador de margem máxima tem alto potencial de generalização, para dados linearmente separáveis;<br><br>
# <li>Um classificador de margem suave (vetores de suporte) introduz um pouco mais de viés ao permitir erros de treino, mas, com isso, aumenta o potencial de generalização, e pode ser aplicável a dados que não são exatamente linearmente separáveis;<br><br>
# <li>A fronteira de decisão de um classificador de margem sempre será linear no espaço de features;<br><br>
# <li>Se os dados não forem linearmente separáveis no espaço original (de input), podemos fazer um feature map para levá-los para um espaço de features onde haja separabilidade linear;<br><br>
# <li>A única coisa que importa pro SVM é o produto interno entre as observações no espaço de features;<br><br>
# <li>Uma função de kernel permite que calculemos o produto interno no espaço de features sem a necessidade de explicitamente aplicar o feature map.
# </ul>
# </span>
# <br>
# </div>

# %% [markdown]
# Da mesma forma que existem infinitos feature maps possíveis, a variedade de kernels também é imensa! Apesar dos kernels oferecerem uma vantagem operacional absurda com relação à aplicação explícita do feature map, o problema de escolha de um kernel adequado para um determinado problema ainda existe.
#
# Na prática, existem algumas formas de propor kernels, mas este não é um tema fácil. Existe todo um conjunto de métodos e técnicas que se utilizam de kernels para tarefas de aprendizagem, os chamados [métodos de kernel](https://en.wikipedia.org/wiki/Kernel_method).
#
# Apesar da enorme liberdade no design de kernels, há algumas classes particulares de kernels que são comumente utilizados:
#
# - Linear kernel: $\kappa_\Phi(\vec{x}, \vec{x}') = \langle \vec{x}, \vec{x}'\rangle $
# <br><br>
# - Polynomial kernel: $\kappa_\Phi(\vec{x}, \vec{x}') = (\gamma \langle \vec{x}, \vec{x}'\rangle + r)^d$
# <br><br>
# - Radial Basis Function (RBF) kernel: $\kappa_\Phi(\vec{x}, \vec{x}') = \exp(-\gamma \|\vec{x}-\vec{x}'\|^2)$
# <br><br>
# - Sigmoid kernel: $\kappa_\Phi(\vec{x}, \vec{x}') = \tanh(\gamma \langle \vec{x},\vec{x}'\rangle + r)$
#
# > No exemplo explícito que fizemos acima, usamos justamente um kernel polinomial com $r=\gamma=1$ e $d=2$!
#
# Note que a dependência funcional dos kernels muda, dependendo exatamente do feature map específico que eles representam. No entanto, em todos os casos, as features no espaço de input são utilizadas, o que garante a eficiência!

# %% [markdown]
# __________
#
# Agora que entendemos o SVM, vamos ver sua aplicação com o sklearn a um problema de classificação!

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 5) SVM na prática com o sklearn
#
# Para construir um classificador SVM com o sklearn, basta usar a classe [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html).
#
# Vamos utilizar o dataset German Credit Risk!

# %% [markdown]
# Para a construção de um modelo SVM, é muinto importante que os dados sejam normalizados!
#
# O motivo é bem simples: como vimos acima, o SVM é completamente baseado no kernel, que por sua vez é dado por um produto interno. Já o produto interno, é altamente dependente da **escala das features** (lembre-se, $\langle \Phi(\vec{x}) , \Phi(\vec{x}') \rangle = \left | \Phi(\vec{x}) \right | \left | \Phi(\vec{x}') \right | \cos \left ({\theta_{\vec{x}, \vec{x}'}} \right )$, isto é, a norma dos vetores influencia o produto interno!).
#
# Portanto, para evitar que efeitos de escala influenciem a classificação, a normalização é um passo extremamente importante!

# %%
# Importar as bibliotecas
import pandas as pd

from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder

from sklearn.impute import SimpleImputer

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split

from sklearn.pipeline import Pipeline

from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# %%
df = pd.read_csv('../datasets/german_credit_data.csv', index_col=0)

# %%
df.head()
# Out:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
#
#    Duration              Purpose  Risk
# 0         6             radio/TV  good
# 1        48             radio/TV   bad
# 2        12            education  good
# 3        42  furniture/equipment  good
# 4        24                  car   bad

# %%
df['Risk'].value_counts(normalize=True)
# Out:
# Risk
# good    0.7
# bad     0.3
# Name: proportion, dtype: float64

# %%
# função que carrega os dados, define quem são as features e é o target, faço treino e teste
# 1º pipeline : substituir os dados faltantes pela média e padronização/normalização dos dados (qdo os dados forem numéricos)
# 2º pipeline: substituir os dados faltantes por uma constante (desconhecido) e aplicar o onehotencoder (dummies)
# Aplicar (transformar) esses 2 pipelines nas colunas (de treino e de teste) 
def pipe_pre_process_german():
    
    # Função para facilitar a gente carregar e transformar os dados de treino e teste de uma única vez 
    df = pd.read_csv("../datasets/german_credit_data.csv", index_col=0)
    
    # Carregar os dados (dataset)
    X=df.drop(columns='Risk')
    y=df['Risk']
    # Definir quem são as features e quem é o target
    # Particionar os dados de treino e teste(validação)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, stratify=y, random_state=42)

    # ==========================================================
    pipe_features_num = Pipeline([("input_num", SimpleImputer(strategy='mean')), #substituir dados faltantes pela média
                                  ("std_scaler", StandardScaler())])            #padronização/normalização dos dados
    # Transformação das colunas numéricas
    features_num = X_train.select_dtypes(include=np.number).columns.tolist()

    # ==========================================================

    # transformação nas colunas categóricas
    pipe_feature_cat = Pipeline([("input_cat", SimpleImputer(strategy='constant', fill_value='unknown')),
                                 ("onehot", OneHotEncoder())])
    features_cat = X_train.select_dtypes(exclude=np.number).columns.tolist()
    # ==========================================================

    # aplicando a transformação nos dados de treino tanto nas colunas numéricas quanto nas colunas categóricas
    pre_processador = ColumnTransformer([("tranfr_num", pipe_features_num, features_num),
                                         ("transf_cat", pipe_feature_cat, features_cat)])
    
    return X_train, X_test, y_train, y_test, pre_processador

# %%
# Função para avaliar o modelo
def metricas_classificao(estimator):
    
    # ============================================
    print("\nMétricas de avaliação de treino")
    
    y_pred_train= estimator.predict(X_train)
    print(confusion_matrix(y_train, y_pred_train))
    
    ConfusionMatrixDisplay.from_predictions(y_train, y_pred_train)
    plt.show()
    
    print(classification_report(y_train, y_pred_train))

    # ============================================

    print("\nMétricas de avaliação de teste")
    y_pred_test = estimator.predict(X_test)
    print(confusion_matrix(y_test, y_pred_test))
    
    print(confusion_matrix(y_test, y_pred_test))
    ConfusionMatrixDisplay.from_predictions(y_test, y_pred_test)
    plt.show()
    
    print(classification_report(y_test, y_pred_test))

# %% [markdown]
# Agora, vamos instanciar a classe do [SVC](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html)!
#
# Perceba que há muitos hiperparâmetros. Vale a pena estudar um pouco mais o fundo o funcionamento de cada um, e sua influência. Para algumas dicas práticas do uso de SVMs com o sklearn, [clique aqui!](https://scikit-learn.org/stable/modules/svm.html#tips-on-practical-use)
#
# Na prática, os principais hiperparâmetros serão `C` e o `gamma` (se o kernel escolhido utilizar este parâmetro, como, por exemplo, o kernel rbf: por isso, o hiperparâmetro `kernel` também é importante!):
#
# - `C`: é um parâmetro de regularização, relacionado com a "suavidade" da margem. Ele controla o tradeoff entre a complexidade da fronteira de decisão, e erros de classificação que são permitidos. Quanto **menor** o C, mais suave será a fronteira de decisão, pois mais erros de classificação são permitidos (isto é, a margem fica **mais larga**); quanto **maior** C, a tolerância a erros de classificação é menor (e a margem fica menos suave, mais complexa);
#
# <img src="https://learnopencv.com/wp-content/uploads/2018/07/svm-parameter-c-example.png" width=500>
#
# - `gamma`: define a influência que cada ponto tem na fronteira de decisão. É a "abertura" do kernel: quanto **maior** o gamma, a influência é de mais curto alcance, e vice-versa;
#
# <img src="https://sgao323.gitbooks.io/artificial-intelligence-projects/content/assets/svm_gamma.png" width=400>
#
# - `kernel`: as opções disponíveis são `linear`, `poly`, `rbf` e `sigmoid`, que apresentamos acima. Também é possível utilizar um kernel personalizado pré-calculado (neste caso, usamos a opção `precomputed`).
#
#
# No que diz respeito a `C` e `gamma`, é importante que valores adequados sejam encontrados com o uso de Grid/Random search, usando **valores exponencialmente espaçados**.

# %%
import matplotlib.pyplot as plt

# Carregar o módulo para o SVM
from sklearn.svm import SVC #carregando o módulo de classificação do SVM

# %%
# usando a primeira função pipe_pre_process_german _> função para organizar os dados e reaproveitar
X_train, X_test, y_train, y_test, pre_processador = pipe_pre_process_german()
# prepara os dados e instacia o modelo
pipe_svc= Pipeline([("pre_process", pre_processador),
                   ("svc", SVC(random_state=42)) ])
 #treinando o modelo
 
pipe_svc.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('tranfr_num',
#                                                   Pipeline(steps=[('input_num',
#                                                                    SimpleImputer()),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Job',
#                                                    'Credit amount',
#                                                    'Duration']),
#                                                  ('transf_cat',
#                                                   Pipeline(steps=[('input_cat',
#                                                                    SimpleImputer(fill_value='unknown',
#                                                                                  strategy='constant')),
#                                                                   ('onehot',
#                                                                    OneHotEncoder())]),
#                                                   ['Sex', 'Housing',
#                                                    'Saving accounts',
#                                                    'Checking account',
#                                                    'Purpose'])])),
#                 ('svc', SVC(random_state=42))])

# %%
#usando a função que fizemos lá em cima
metricas_classificao(pipe_svc)
# Out:
# Métricas de avaliação de treino
# [[102 138]
#  [ 18 542]]
#               precision    recall  f1-score   support
#
#          bad       0.85      0.42      0.57       240
#         good       0.80      0.97      0.87       560
#
#     accuracy                           0.81       800
#    macro avg       0.82      0.70      0.72       800
# weighted avg       0.81      0.81      0.78       800
#
#
# Métricas de avaliação de teste
# [[ 18  42]
#  [  9 131]]
# [[ 18  42]
#  [  9 131]]
#               precision    recall  f1-score   support
#
#          bad       0.67      0.30      0.41        60
#         good       0.76      0.94      0.84       140
#
#     accuracy                           0.74       200
#    macro avg       0.71      0.62      0.63       200
# weighted avg       0.73      0.74      0.71       200

# %% [markdown]
# Agora, podemos montar um gridsearch para otimizar o modelo:

# %%
# usando a primeira função pipe_pre_process_german _> função para organizar os dados e reaproveitar
X_train, X_test, y_train , y_test, pre_processador = pipe_pre_process_german()
# prepara os dados e instacia o modelo
pipe_svc = Pipeline([('pre_process', pre_processador),
                     ('svc', SVC(random_state=42))])

pipe_svc.fit(X_train, y_train)

# ===================================================================================

# escolhendo a lista de combinações para usar o no gridsearch 
param_grid_svc = {
                    "svc__kernel": ['linear', 'poly', 'rbf'],
                    "svc__C":np.logspace(-2,2,5),
                    "svc__gamma": np.logspace(-2,2,5)
}

splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid_svc = GridSearchCV( estimator=pipe_svc,
                        param_grid=param_grid_svc,
                        scoring= "f1_weighted",
                        cv= splitter,
                        verbose=10,
                        n_jobs=-1  
)

grid_svc.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 75 candidates, totalling 375 fits
# [CV 3/5; 1/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=linear...........
# [CV 3/5; 1/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 3/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 3/5; 3/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 1/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=linear...........
# [CV 4/5; 3/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 1/5; 2/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=poly.............
# [CV 2/5; 2/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=poly.............
# [CV 2/5; 1/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 4/5; 3/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 3/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 1/5; 2/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 2/5; 2/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 1/5; 4/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=linear............
# [CV 2/5; 4/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=linear............
# [CV 5/5; 3/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 4/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=linear............
# [CV 4/5; 4/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=linear............
# [CV 2/5; 3/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 1/5; 4/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 5/5; 4/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=linear............
# [CV 2/5; 4/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 1/5; 5/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=poly..............
# [CV 3/5; 4/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 4/5; 4/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 2/5; 5/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=poly..............
# [CV 5/5; 4/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 4/5; 5/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=poly..............
# [CV 2/5; 3/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 5/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=poly..............
# [CV 1/5; 5/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 5/5; 5/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=poly..............
# [CV 2/5; 5/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=poly;, score=0.591 total time=   0.1s
# [CV 1/5; 6/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 2/5; 6/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 4/5; 5/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 3/5; 6/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 3/5; 2/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=poly.............
# [CV 3/5; 5/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=poly;, score=0.573 total time=   0.1s
# [CV 5/5; 5/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 4/5; 6/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 6/75] START svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 2/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=poly.............[CV 1/5; 1/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=linear...........
# [CV 2/5; 6/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 6/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 7/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=linear............
# [CV 1/5; 7/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=linear............
#
# [CV 3/5; 6/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 7/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=linear............
# [CV 4/5; 1/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=linear...........
# [CV 5/5; 1/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=linear...........
# [CV 5/5; 6/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 7/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=linear............
# [CV 1/5; 1/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 2/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 1/5; 7/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 5/5; 7/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=linear............
# [CV 4/5; 6/75] END svc__C=0.01, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 8/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=poly..............
# [CV 2/5; 7/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 2/5; 8/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=poly..............
# [CV 4/5; 1/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 7/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 8/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=poly..............
# [CV 5/5; 2/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 5/5; 1/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 4/5; 8/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=poly..............
# [CV 4/5; 7/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 8/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=poly..............
# [CV 1/5; 9/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 1/5; 8/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=poly;, score=0.714 total time=   0.1s
# [CV 2/5; 9/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 3/5; 9/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 2/5; 8/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=poly;, score=0.735 total time=   0.1s
# [CV 4/5; 9/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 5/5; 7/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 9/75] START svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 1/5; 10/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=linear..........
# [CV 2/5; 10/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=linear..........
# [CV 3/5; 8/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=poly;, score=0.645 total time=   0.1s
# [CV 3/5; 10/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=linear..........
# [CV 5/5; 8/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=poly;, score=0.681 total time=   0.1s
# [CV 2/5; 9/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 8/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=poly;, score=0.690 total time=   0.1s
# [CV 4/5; 10/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=linear..........
# [CV 5/5; 10/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=linear..........
# [CV 3/5; 9/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 9/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 9/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 11/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=poly............
# [CV 2/5; 11/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=poly............
# [CV 4/5; 2/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=poly.............
# [CV 4/5; 11/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=poly............
# [CV 3/5; 11/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=poly............
# [CV 1/5; 3/75] START svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 1/5; 10/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 2/5; 10/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 11/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=poly............
# [CV 3/5; 10/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 1/5; 12/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 2/5; 12/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 4/5; 10/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 3/5; 12/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 5/5; 9/75] END svc__C=0.01, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 10/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 4/5; 2/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 4/5; 12/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 5/5; 12/75] START svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 2/5; 12/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 12/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s[CV 1/5; 13/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=linear.........
#
# [CV 2/5; 13/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=linear.........
# [CV 1/5; 3/75] END svc__C=0.01, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s[CV 3/5; 13/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=linear.........
#
# [CV 4/5; 11/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=poly;, score=0.659 total time=   0.1s
# [CV 4/5; 13/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=linear.........
# [CV 4/5; 12/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 13/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 13/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=linear.........
# [CV 1/5; 14/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=poly...........
# [CV 2/5; 13/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 13/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 2/5; 14/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=poly...........
# [CV 1/5; 12/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.2s
# [CV 3/5; 14/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=poly...........
# [CV 4/5; 14/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=poly...........
# [CV 5/5; 12/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s[CV 5/5; 14/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=poly...........
#
# [CV 1/5; 15/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf............
# [CV 4/5; 13/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 2/5; 15/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf............
# [CV 1/5; 11/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=poly;, score=0.598 total time=   0.2s
# [CV 3/5; 15/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf............
# [CV 5/5; 13/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 2/5; 11/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=poly;, score=0.691 total time=   0.3s
# [CV 4/5; 15/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf............
# [CV 5/5; 15/75] START svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf............
# [CV 1/5; 15/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 16/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=linear...........
# [CV 1/5; 14/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=poly;, score=0.598 total time=   0.2s
# [CV 3/5; 11/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=poly;, score=0.590 total time=   0.3s
# [CV 2/5; 16/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=linear...........
# [CV 3/5; 16/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=linear...........
# [CV 2/5; 15/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 16/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=linear...........
# [CV 3/5; 15/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 16/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=linear;, score=0.702 total time=   0.1s
# [CV 5/5; 16/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=linear...........
# [CV 1/5; 17/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=poly.............
# [CV 5/5; 15/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 17/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=poly.............
# [CV 2/5; 16/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=linear;, score=0.576 total time=   0.0s
# [CV 3/5; 17/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=poly.............
# [CV 3/5; 16/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=linear;, score=0.617 total time=   0.0s
# [CV 4/5; 17/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=poly.............
# [CV 4/5; 16/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=linear;, score=0.672 total time=   0.0s
# [CV 1/5; 17/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 5/5; 16/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=linear;, score=0.674 total time=   0.0s
# [CV 5/5; 17/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=poly.............
# [CV 4/5; 15/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 18/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 5/5; 11/75] END svc__C=0.01, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 2/5; 18/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 3/5; 18/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 4/5; 18/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 2/5; 17/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 5/5; 18/75] START svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 3/5; 17/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 1/5; 19/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=linear............
# [CV 4/5; 17/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 2/5; 19/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=linear............
# [CV 3/5; 14/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=poly;, score=0.634 total time=   0.2s
# [CV 3/5; 19/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=linear............
# [CV 5/5; 17/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 4/5; 19/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=linear............
# [CV 1/5; 18/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 19/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=linear............
# [CV 3/5; 18/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 20/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=poly..............
# [CV 4/5; 18/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 19/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=linear;, score=0.702 total time=   0.0s
# [CV 2/5; 20/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=poly..............
# [CV 3/5; 20/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=poly..............
# [CV 2/5; 18/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 20/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=poly..............
# [CV 4/5; 19/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=linear;, score=0.672 total time=   0.0s
# [CV 2/5; 19/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 20/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=poly..............[CV 1/5; 21/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 19/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=linear;, score=0.674 total time=   0.1s
#
# [CV 2/5; 21/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 3/5; 19/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=linear;, score=0.617 total time=   0.1s
# [CV 3/5; 21/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 1/5; 20/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=poly;, score=0.588 total time=   0.1s
# [CV 4/5; 21/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 18/75] END svc__C=0.1, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 21/75] START svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 14/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 2/5; 20/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=poly;, score=0.618 total time=   0.1s
# [CV 3/5; 20/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=poly;, score=0.611 total time=   0.1s
# [CV 2/5; 22/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=linear............
# [CV 1/5; 22/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=linear............
# [CV 3/5; 22/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=linear............
# [CV 2/5; 21/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 20/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=poly;, score=0.591 total time=   0.1s
# [CV 4/5; 22/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=linear............
# [CV 5/5; 22/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=linear............
# [CV 4/5; 21/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 23/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=poly..............
# [CV 5/5; 20/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=poly;, score=0.605 total time=   0.1s
# [CV 2/5; 23/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=poly..............[CV 1/5; 22/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=linear;, score=0.702 total time=   0.0s
#
# [CV 3/5; 23/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=poly..............
# [CV 2/5; 22/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 4/5; 23/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=poly..............
# [CV 5/5; 22/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=linear;, score=0.674 total time=   0.0s
# [CV 5/5; 23/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=poly..............
# [CV 3/5; 21/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s[CV 1/5; 21/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
#
# [CV 1/5; 24/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 2/5; 24/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 4/5; 22/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=linear;, score=0.672 total time=   0.1s
# [CV 3/5; 22/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=linear;, score=0.617 total time=   0.1s
# [CV 3/5; 24/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 4/5; 24/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 5/5; 21/75] END svc__C=0.1, svc__gamma=0.1, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 24/75] START svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 2/5; 14/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=poly;, score=0.661 total time=   0.5s
# [CV 1/5; 23/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=poly;, score=0.648 total time=   0.1s
# [CV 1/5; 25/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=linear...........
# [CV 2/5; 24/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 24/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 25/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=linear...........
# [CV 4/5; 23/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=poly;, score=0.709 total time=   0.1s
# [CV 3/5; 25/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=linear...........
# [CV 3/5; 23/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=poly;, score=0.587 total time=   0.1s
# [CV 4/5; 25/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=linear...........
# [CV 1/5; 26/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=poly.............[CV 5/5; 25/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=linear...........
#
# [CV 5/5; 24/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 23/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=poly;, score=0.703 total time=   0.1s
# [CV 1/5; 24/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 26/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=poly.............
# [CV 4/5; 24/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 26/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=poly.............
# [CV 1/5; 25/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=linear;, score=0.702 total time=   0.0s
# [CV 5/5; 26/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=poly.............
# [CV 5/5; 23/75] END svc__C=0.1, svc__gamma=1.0, svc__kernel=poly;, score=0.671 total time=   0.1s
# [CV 1/5; 27/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 2/5; 27/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 3/5; 25/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=linear;, score=0.617 total time=   0.0s
# [CV 4/5; 26/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=poly.............
# [CV 3/5; 27/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 2/5; 25/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 5/5; 25/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=linear;, score=0.674 total time=   0.1s
# [CV 5/5; 27/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 4/5; 25/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=linear;, score=0.672 total time=   0.1s
# [CV 2/5; 28/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=linear..........
# [CV 4/5; 28/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=linear..........
# [CV 1/5; 27/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 27/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 29/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=poly............
# [CV 4/5; 28/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=linear;, score=0.672 total time=   0.0s
# [CV 5/5; 28/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=linear..........
# [CV 3/5; 29/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=poly............
# [CV 4/5; 14/75] END svc__C=0.01, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.7s
# [CV 2/5; 28/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=linear;, score=0.576 total time=   0.1s
# [CV 3/5; 28/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=linear..........[CV 3/5; 27/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
#
# [CV 4/5; 27/75] START svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 5/5; 29/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=poly............
# [CV 5/5; 27/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 28/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=linear..........
# [CV 1/5; 26/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=poly;, score=0.598 total time=   0.1s
# [CV 2/5; 30/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 5/5; 28/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=linear;, score=0.674 total time=   0.0s
# [CV 4/5; 30/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 1/5; 28/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=linear;, score=0.702 total time=   0.0s
# [CV 1/5; 31/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=linear...........
# [CV 3/5; 28/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=linear;, score=0.617 total time=   0.1s
# [CV 3/5; 31/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=linear...........
# [CV 2/5; 30/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 30/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 4/5; 27/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 31/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=linear...........
# [CV 1/5; 31/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=linear;, score=0.720 total time=   0.1s
# [CV 2/5; 31/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=linear...........
# [CV 4/5; 30/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 30/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 1/5; 29/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=poly;, score=0.598 total time=   0.1s
# [CV 2/5; 29/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=poly............
# [CV 3/5; 31/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=linear;, score=0.636 total time=   0.1s
# [CV 4/5; 31/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=linear...........
# [CV 2/5; 31/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 2/5; 32/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=poly.............
# [CV 5/5; 31/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=linear;, score=0.686 total time=   0.1s
# [CV 1/5; 32/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=poly.............
# [CV 5/5; 30/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 32/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=poly.............
# [CV 3/5; 26/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=poly;, score=0.592 total time=   0.3s
# [CV 1/5; 33/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 3/5; 30/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 29/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=poly;, score=0.634 total time=   0.2s
# [CV 4/5; 29/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=poly............
# [CV 3/5; 33/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 4/5; 31/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=linear;, score=0.703 total time=   0.1s
# [CV 5/5; 33/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 2/5; 32/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 3/5; 32/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=poly.............
# [CV 1/5; 32/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 4/5; 32/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 5/5; 32/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=poly.............
# [CV 2/5; 34/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=linear............
# [CV 1/5; 33/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 33/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 2/5; 26/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=poly;, score=0.647 total time=   0.4s
# [CV 4/5; 34/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=linear............
# [CV 3/5; 32/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 1/5; 35/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=poly..............
# [CV 5/5; 32/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 3/5; 35/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=poly..............
# [CV 5/5; 26/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 5/5; 35/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=poly..............
# [CV 5/5; 33/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 33/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.635 total time=   0.1s
# [CV 4/5; 33/75] START svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf..............
# [CV 1/5; 34/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=linear............
# [CV 2/5; 34/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/5; 34/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=linear............
# [CV 1/5; 35/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=poly;, score=0.664 total time=   0.0s
# [CV 2/5; 35/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=poly..............
# [CV 3/5; 35/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5; 35/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=poly..............
# [CV 5/5; 29/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 1/5; 30/75] START svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 2/5; 33/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 36/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 35/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=poly;, score=0.666 total time=   0.1s
# [CV 1/5; 36/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 4/5; 26/75] END svc__C=0.1, svc__gamma=10.0, svc__kernel=poly;, score=0.675 total time=   0.5s
# [CV 4/5; 36/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 2/5; 35/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=poly;, score=0.728 total time=   0.0s
# [CV 4/5; 35/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=poly;, score=0.671 total time=   0.0s
# [CV 1/5; 37/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=linear............
# [CV 3/5; 34/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=linear;, score=0.636 total time=   0.1s
# [CV 5/5; 37/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=linear............
# [CV 1/5; 34/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=linear;, score=0.720 total time=   0.1s
# [CV 4/5; 33/75] END svc__C=1.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 38/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=poly..............
# [CV 3/5; 39/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 4/5; 34/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=linear;, score=0.703 total time=   0.1s
# [CV 5/5; 34/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=linear............
# [CV 2/5; 40/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=linear...........
# [CV 2/5; 36/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.757 total time=   0.1s
# [CV 3/5; 36/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 1/5; 36/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.692 total time=   0.1s
# [CV 1/5; 41/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=poly.............
# [CV 5/5; 37/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=linear;, score=0.686 total time=   0.0s
# [CV 1/5; 38/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=poly..............
# [CV 1/5; 30/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 36/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.678 total time=   0.1s
# [CV 5/5; 36/75] START svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf...............
# [CV 5/5; 41/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=poly.............
# [CV 1/5; 37/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=linear;, score=0.720 total time=   0.1s
# [CV 2/5; 37/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=linear............
# [CV 3/5; 36/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.606 total time=   0.1s
# [CV 3/5; 39/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.600 total time=   0.1s
# [CV 4/5; 39/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 4/5; 42/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 5/5; 34/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=linear;, score=0.686 total time=   0.1s
# [CV 3/5; 43/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=linear..........
# [CV 2/5; 40/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/5; 40/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=linear...........
# [CV 5/5; 36/75] END svc__C=1.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.723 total time=   0.1s
# [CV 2/5; 44/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=poly............
# [CV 2/5; 37/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 3/5; 37/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=linear............
# [CV 3/5; 40/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5; 40/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=linear...........
# [CV 1/5; 38/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=poly;, score=0.656 total time=   0.1s
# [CV 2/5; 38/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=poly..............
# [CV 4/5; 42/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.588 total time=   0.1s
# [CV 5/5; 42/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 4/5; 39/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.623 total time=   0.1s
# [CV 5/5; 39/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 4/5; 38/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=poly;, score=0.640 total time=   0.2s
# [CV 5/5; 38/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=poly..............
# [CV 3/5; 43/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=linear;, score=0.636 total time=   0.1s
# [CV 4/5; 43/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=linear..........
# [CV 4/5; 40/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=linear;, score=0.703 total time=   0.0s
# [CV 5/5; 40/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=linear...........
# [CV 3/5; 37/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=linear;, score=0.636 total time=   0.1s
# [CV 4/5; 37/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=linear............
# [CV 5/5; 42/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.573 total time=   0.1s
# [CV 1/5; 43/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=linear..........
# [CV 5/5; 39/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.628 total time=   0.1s
# [CV 1/5; 40/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=linear...........
# [CV 5/5; 40/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=linear;, score=0.686 total time=   0.0s
# [CV 2/5; 29/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=poly;, score=0.661 total time=   0.5s
# [CV 1/5; 45/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 5/5; 45/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 4/5; 37/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=linear;, score=0.703 total time=   0.1s
# [CV 1/5; 43/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=linear;, score=0.720 total time=   0.0s
# [CV 2/5; 43/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=linear..........
# [CV 4/5; 46/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=linear..........
# [CV 4/5; 43/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=linear;, score=0.703 total time=   0.1s
# [CV 1/5; 40/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=linear;, score=0.720 total time=   0.0s
# [CV 5/5; 43/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=linear..........
# [CV 3/5; 47/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=poly............
# [CV 1/5; 41/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=poly;, score=0.598 total time=   0.3s
# [CV 2/5; 41/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=poly.............
# [CV 2/5; 38/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=poly;, score=0.655 total time=   0.2s
# [CV 3/5; 38/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=poly..............
# [CV 1/5; 45/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 2/5; 45/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 2/5; 43/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=linear;, score=0.761 total time=   0.1s
# [CV 2/5; 48/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf.............
# [CV 5/5; 45/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 1/5; 46/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=linear..........
# [CV 5/5; 43/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=linear;, score=0.686 total time=   0.1s
# [CV 1/5; 44/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=poly............
# [CV 4/5; 46/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=linear;, score=0.712 total time=   0.1s
# [CV 5/5; 46/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=linear..........
# [CV 3/5; 47/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=poly;, score=0.573 total time=   0.1s
# [CV 4/5; 47/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=poly............
# [CV 2/5; 48/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.713 total time=   0.1s
# [CV 3/5; 48/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf.............
# [CV 2/5; 45/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 3/5; 45/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 5/5; 38/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=poly;, score=0.631 total time=   0.3s
# [CV 1/5; 39/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 3/5; 38/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=poly;, score=0.585 total time=   0.1s
# [CV 5/5; 41/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 1/5; 42/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 1/5; 46/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=linear;, score=0.728 total time=   0.1s
# [CV 2/5; 46/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=linear..........
# [CV 4/5; 47/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 5/5; 47/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=poly............
# [CV 1/5; 49/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=linear...........
# [CV 5/5; 46/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=linear;, score=0.691 total time=   0.1s
# [CV 1/5; 47/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=poly............
# [CV 3/5; 45/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 45/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf.............
# [CV 4/5; 29/75] END svc__C=0.1, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.7s
# [CV 5/5; 49/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=linear...........
# [CV 1/5; 42/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.573 total time=   0.1s
# [CV 2/5; 42/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 1/5; 39/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.592 total time=   0.1s
# [CV 2/5; 39/75] START svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf...............
# [CV 3/5; 48/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.626 total time=   0.1s
# [CV 4/5; 48/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf.............
# [CV 1/5; 47/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.0s
# [CV 2/5; 47/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=poly............
# [CV 5/5; 47/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=poly;, score=0.576 total time=   0.1s
# [CV 1/5; 48/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf.............
# [CV 2/5; 46/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=linear;, score=0.756 total time=   0.1s
# [CV 3/5; 46/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=linear..........
# [CV 2/5; 42/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.591 total time=   0.1s
# [CV 3/5; 42/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf..............
# [CV 2/5; 47/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=poly;, score=0.591 total time=   0.0s
# [CV 4/5; 45/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 50/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=poly.............
# [CV 3/5; 51/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf..............
# [CV 2/5; 39/75] END svc__C=1.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.587 total time=   0.1s
# [CV 2/5; 52/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=linear...........
# [CV 5/5; 49/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=linear;, score=0.691 total time=   0.1s
# [CV 1/5; 50/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=poly.............
# [CV 1/5; 44/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=poly;, score=0.598 total time=   0.3s
# [CV 1/5; 53/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=poly.............
# [CV 4/5; 48/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.693 total time=   0.1s
# [CV 5/5; 48/75] START svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf.............
# [CV 2/5; 44/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=poly;, score=0.661 total time=   0.5s
# [CV 3/5; 44/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=poly............
# [CV 1/5; 48/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.691 total time=   0.1s
# [CV 4/5; 50/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=poly;, score=0.690 total time=   0.1s
# [CV 5/5; 50/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=poly.............
# [CV 3/5; 51/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.674 total time=   0.1s
# [CV 4/5; 51/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf..............
# [CV 5/5; 53/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=poly.............
# [CV 1/5; 50/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=poly;, score=0.714 total time=   0.0s
# [CV 2/5; 50/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=poly.............
# [CV 3/5; 42/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 54/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=rbf..............
# [CV 1/5; 49/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=linear;, score=0.728 total time=   0.2s
# [CV 2/5; 49/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=linear...........
# [CV 5/5; 48/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.726 total time=   0.1s
# [CV 3/5; 55/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=linear..........
# [CV 3/5; 46/75] END svc__C=10.0, svc__gamma=0.01, svc__kernel=linear;, score=0.641 total time=   0.1s
# [CV 5/5; 50/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=poly;, score=0.681 total time=   0.1s
# [CV 4/5; 51/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.723 total time=   0.1s
# [CV 1/5; 51/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf..............
# [CV 5/5; 51/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf..............
# [CV 2/5; 56/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=poly............
# [CV 2/5; 52/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=linear;, score=0.756 total time=   0.1s
# [CV 3/5; 52/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=linear...........
# [CV 2/5; 50/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=poly;, score=0.735 total time=   0.1s
# [CV 3/5; 50/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=poly.............
# [CV 4/5; 54/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.645 total time=   0.1s
# [CV 5/5; 54/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=rbf..............
# [CV 1/5; 51/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.692 total time=   0.1s
# [CV 2/5; 51/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf..............
# [CV 5/5; 51/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.699 total time=   0.1s
# [CV 1/5; 52/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=linear...........
# [CV 3/5; 50/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=poly;, score=0.645 total time=   0.1s
# [CV 1/5; 57/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 3/5; 55/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=linear;, score=0.641 total time=   0.1s
# [CV 4/5; 55/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=linear..........
# [CV 2/5; 49/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=linear;, score=0.756 total time=   0.2s
# [CV 3/5; 49/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=linear...........
# [CV 1/5; 53/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=poly;, score=0.598 total time=   0.2s
# [CV 2/5; 53/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=poly.............
# [CV 2/5; 51/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.758 total time=   0.1s
# [CV 5/5; 57/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 5/5; 54/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.641 total time=   0.1s
# [CV 1/5; 55/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=linear..........
# [CV 3/5; 52/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=linear;, score=0.641 total time=   0.1s
# [CV 4/5; 52/75] START svc__C=10.0, svc__gamma=1.0, svc__kernel=linear...........
# [CV 1/5; 57/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.567 total time=   0.1s
# [CV 2/5; 57/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=rbf.............
# [CV 1/5; 52/75] END svc__C=10.0, svc__gamma=1.0, svc__kernel=linear;, score=0.728 total time=   0.1s
# [CV 4/5; 58/75] START svc__C=10.0, svc__gamma=100.0, svc__kernel=linear.........
# [CV 3/5; 49/75] END svc__C=10.0, svc__gamma=0.1, svc__kernel=linear;, score=0.641 total time=   0.1s
# [CV 4/5; 49/75] START svc__C=10.0, svc__gamma=0.1, svc__kernel=linear...........
# [CV 5/5; 57/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.564 total time=   0.1s
# [CV 1/5; 58/75] START svc__C=10.0, svc__gamma=100.0, svc__kernel=linear.........
# [CV 2/5; 41/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=poly;, score=0.661 total time=   0.7s
# [CV 3/5; 41/75] START svc__C=1.0, svc__gamma=10.0, svc__kernel=poly.............
# [CV 1/5; 55/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=linear;, score=0.728 total time=   0.1s
# [CV 2/5; 55/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=linear..........
# [CV 4/5; 55/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=linear;, score=0.712 total time=   0.1s
# [CV 5/5; 55/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=linear..........
# ...
# [CV 4/5; 66/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf.............
# [CV 5/5; 65/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=poly;, score=0.671 total time=   0.1s
# [CV 1/5; 66/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf.............
# [CV 5/5; 63/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=rbf;, score=0.706 total time=   0.1s
# [CV 1/5; 64/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=linear..........
# [CV 2/5; 65/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=poly;, score=0.703 total time=   0.1s
# [CV 3/5; 65/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=poly............
# [CV 4/5; 66/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.686 total time=   0.1s
# [CV 5/5; 66/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf.............
# [CV 1/5; 66/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.676 total time=   0.1s
# [CV 2/5; 66/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf.............
# [CV 1/5; 61/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=linear;, score=0.728 total time=   0.6s
# [CV 4/5; 41/75] END svc__C=1.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 3/5; 67/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=linear..........
# [CV 2/5; 61/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=linear.........
# [CV 4/5; 44/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.7s
# [CV 5/5; 44/75] START svc__C=1.0, svc__gamma=100.0, svc__kernel=poly............
# [CV 3/5; 65/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=poly;, score=0.587 total time=   0.1s
# [CV 4/5; 65/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=poly............
# [CV 2/5; 66/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.689 total time=   0.1s
# [CV 3/5; 66/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf.............
# [CV 4/5; 59/75] END svc__C=10.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.5s
# [CV 5/5; 59/75] START svc__C=10.0, svc__gamma=100.0, svc__kernel=poly...........
# [CV 5/5; 66/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.707 total time=   0.1s
# [CV 1/5; 67/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=linear..........
# [CV 4/5; 65/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=poly;, score=0.709 total time=   0.1s
# [CV 2/5; 59/75] END svc__C=10.0, svc__gamma=100.0, svc__kernel=poly;, score=0.661 total time=   0.6s
# [CV 1/5; 69/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf.............[CV 2/5; 68/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=poly............
#
# [CV 3/5; 66/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=rbf;, score=0.632 total time=   0.1s
# [CV 5/5; 69/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf.............
# [CV 3/5; 56/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=poly;, score=0.634 total time=   0.3s
# [CV 4/5; 56/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=poly............
# [CV 5/5; 69/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.641 total time=   0.1s
# [CV 1/5; 70/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=linear.........
# [CV 1/5; 69/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.569 total time=   0.1s
# [CV 2/5; 69/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf.............
# [CV 2/5; 69/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.609 total time=   0.1s
# [CV 3/5; 69/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf.............
# [CV 5/5; 61/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=linear;, score=0.686 total time=   0.9s
# [CV 1/5; 62/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=poly...........
# [CV 5/5; 59/75] END svc__C=10.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.3s
# [CV 1/5; 60/75] START svc__C=10.0, svc__gamma=100.0, svc__kernel=rbf............
# [CV 5/5; 44/75] END svc__C=1.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.3s
# [CV 4/5; 70/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=linear.........
# [CV 3/5; 69/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.603 total time=   0.1s
# [CV 4/5; 69/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf.............
# [CV 1/5; 64/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=linear;, score=0.728 total time=   0.5s
# [CV 3/5; 71/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=poly...........
# [CV 1/5; 62/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=poly;, score=0.588 total time=   0.1s
# [CV 2/5; 62/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=poly...........
# [CV 1/5; 60/75] END svc__C=10.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.573 total time=   0.1s
# [CV 2/5; 72/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf............
# [CV 2/5; 62/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=poly;, score=0.618 total time=   0.0s
# [CV 3/5; 62/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=poly...........
# [CV 4/5; 69/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=rbf;, score=0.655 total time=   0.1s
# [CV 1/5; 73/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=linear........
# [CV 2/5; 72/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.584 total time=   0.1s
# [CV 3/5; 72/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf............
# [CV 3/5; 62/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=poly;, score=0.611 total time=   0.1s
# [CV 5/5; 73/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=linear........
# [CV 3/5; 72/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.584 total time=   0.1s
# [CV 3/5; 67/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=linear;, score=0.641 total time=   0.6s
# [CV 4/5; 67/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=linear..........[CV 4/5; 72/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf............
#
# [CV 3/5; 71/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=poly;, score=0.634 total time=   0.2s
# [CV 4/5; 71/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=poly...........
# [CV 4/5; 56/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.5s
# [CV 5/5; 56/75] START svc__C=10.0, svc__gamma=10.0, svc__kernel=poly............
# [CV 2/5; 64/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=linear;, score=0.756 total time=   1.0s
# [CV 3/5; 64/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=linear..........
# [CV 2/5; 68/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=poly;, score=0.647 total time=   0.5s
# [CV 3/5; 68/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=poly............
# [CV 1/5; 70/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=linear;, score=0.728 total time=   0.5s
# [CV 2/5; 70/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=linear.........
# [CV 4/5; 72/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.601 total time=   0.1s
# [CV 5/5; 72/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf............
# [CV 5/5; 72/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.564 total time=   0.1s
# [CV 4/5; 74/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=poly..........
# [CV 1/5; 67/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=linear;, score=0.728 total time=   0.7s
# [CV 2/5; 67/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=linear..........
# [CV 3/5; 68/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=poly;, score=0.592 total time=   0.3s
# [CV 4/5; 68/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=poly............
# [CV 4/5; 71/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 5/5; 71/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=poly...........
# [CV 5/5; 56/75] END svc__C=10.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.4s
# [CV 4/5; 70/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=linear;, score=0.703 total time=   0.7s
# [CV 5/5; 70/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=linear.........[CV 3/5; 75/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf...........
#
# [CV 3/5; 75/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 4/5; 75/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf...........
# [CV 4/5; 68/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=poly;, score=0.675 total time=   0.3s
# [CV 5/5; 68/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=poly............
# [CV 1/5; 73/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=linear;, score=0.728 total time=   0.8s
# [CV 2/5; 73/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=linear........
# [CV 4/5; 75/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.591 total time=   0.1s
# [CV 5/5; 75/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf...........
# [CV 5/5; 71/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=poly;, score=0.650 total time=   0.3s
# [CV 1/5; 72/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf............
# [CV 4/5; 67/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=linear;, score=0.703 total time=   0.8s
# [CV 5/5; 67/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=linear..........
# [CV 3/5; 64/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=linear;, score=0.641 total time=   0.7s
# [CV 4/5; 64/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=linear..........
# [CV 1/5; 72/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=rbf;, score=0.567 total time=   0.1s
# [CV 5/5; 73/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=linear;, score=0.686 total time=   0.9s
# [CV 1/5; 74/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=poly..........
# [CV 5/5; 75/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.576 total time=   0.1s
# [CV 5/5; 68/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=poly;, score=0.650 total time=   0.3s
# [CV 4/5; 74/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.8s
# [CV 5/5; 74/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=poly..........
# [CV 2/5; 61/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=linear;, score=0.756 total time=   1.6s
# [CV 3/5; 61/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=linear.........
# [CV 1/5; 74/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=poly;, score=0.598 total time=   0.1s
# [CV 2/5; 74/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=poly..........
# [CV 5/5; 70/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=linear;, score=0.686 total time=   0.6s
# [CV 1/5; 71/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=poly...........
# [CV 5/5; 74/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=poly;, score=0.650 total time=   0.2s
# [CV 1/5; 75/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf...........
# [CV 1/5; 71/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=poly;, score=0.598 total time=   0.1s
# [CV 2/5; 71/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=poly...........
# [CV 1/5; 75/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.573 total time=   0.1s
# [CV 2/5; 75/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf...........
# [CV 4/5; 64/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=linear;, score=0.703 total time=   0.4s
# [CV 5/5; 64/75] START svc__C=100.0, svc__gamma=0.1, svc__kernel=linear..........
# [CV 2/5; 70/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=linear;, score=0.756 total time=   1.2s
# [CV 3/5; 70/75] START svc__C=100.0, svc__gamma=10.0, svc__kernel=linear.........
# [CV 2/5; 75/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=rbf;, score=0.591 total time=   0.1s
# [CV 2/5; 67/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=linear;, score=0.756 total time=   1.1s
# [CV 5/5; 67/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=linear;, score=0.686 total time=   0.6s
# [CV 1/5; 68/75] START svc__C=100.0, svc__gamma=1.0, svc__kernel=poly............
# [CV 2/5; 74/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=poly;, score=0.661 total time=   0.5s
# [CV 3/5; 74/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=poly..........
# [CV 3/5; 61/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=linear;, score=0.641 total time=   0.5s
# [CV 4/5; 61/75] START svc__C=100.0, svc__gamma=0.01, svc__kernel=linear.........
# [CV 1/5; 68/75] END svc__C=100.0, svc__gamma=1.0, svc__kernel=poly;, score=0.598 total time=   0.1s
# [CV 2/5; 71/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=poly;, score=0.661 total time=   0.4s
# [CV 2/5; 73/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=linear;, score=0.756 total time=   0.9s
# [CV 3/5; 73/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=linear........
# [CV 3/5; 74/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=poly;, score=0.634 total time=   0.2s
# [CV 3/5; 70/75] END svc__C=100.0, svc__gamma=10.0, svc__kernel=linear;, score=0.641 total time=   0.5s
# [CV 5/5; 64/75] END svc__C=100.0, svc__gamma=0.1, svc__kernel=linear;, score=0.686 total time=   0.5s
# [CV 4/5; 61/75] END svc__C=100.0, svc__gamma=0.01, svc__kernel=linear;, score=0.703 total time=   0.4s
# [CV 3/5; 73/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=linear;, score=0.641 total time=   0.4s
# [CV 4/5; 73/75] START svc__C=100.0, svc__gamma=100.0, svc__kernel=linear........
# [CV 4/5; 73/75] END svc__C=100.0, svc__gamma=100.0, svc__kernel=linear;, score=0.703 total time=   0.4s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=Pipeline(steps=[('pre_process',
#                                         ColumnTransformer(transformers=[('tranfr_num',
#                                                                          Pipeline(steps=[('input_num',
#                                                                                           SimpleImputer()),
#                                                                                          ('std_scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['Age',
#                                                                           'Job',
#                                                                           'Credit '
#                                                                           'amount',
#                                                                           'Duration']),
#                                                                         ('transf_cat',
#                                                                          Pipeline(steps=[('input_cat',
#                                                                                           SimpleImputer(fill_value...
#                                                                                                         strategy='constant')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Sex',
#                                                                           'Housing',
#                                                                           'Saving '
#                                                                           'accounts',
#                                                                           'Checking '
#                                                                           'account',
#                                                                           'Purpose'])])),
#                                        ('svc', SVC(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'svc__C': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'svc__gamma': array([1.e-02, 1.e-01, 1.e+00, 1.e+01, 1.e+02]),
#                          'svc__kernel': ['linear', 'poly', 'rbf']},
#              scoring='f1_weighted', verbose=10)

# %%
grid_svc.best_params_
# Out:
# {'svc__C': 100.0, 'svc__gamma': 0.01, 'svc__kernel': 'rbf'}

# %%
metricas_classificao(grid_svc)
# Out:
# Métricas de avaliação de treino
# [[107 133]
#  [ 30 530]]
#               precision    recall  f1-score   support
#
#          bad       0.78      0.45      0.57       240
#         good       0.80      0.95      0.87       560
#
#     accuracy                           0.80       800
#    macro avg       0.79      0.70      0.72       800
# weighted avg       0.79      0.80      0.78       800
#
#
# Métricas de avaliação de teste
# [[ 23  37]
#  [ 10 130]]
# [[ 23  37]
#  [ 10 130]]
#               precision    recall  f1-score   support
#
#          bad       0.70      0.38      0.49        60
#         good       0.78      0.93      0.85       140
#
#     accuracy                           0.77       200
#    macro avg       0.74      0.66      0.67       200
# weighted avg       0.75      0.77      0.74       200

# %% [markdown]
# E esse é o SVM para classificação! :)
#
# O SVM també pode ser utilizado para regressão, vamos ver a seguir!

# %%
# lição de casa: continuar o grid search, ver se consegue mais que 0.74!

# %% [markdown]
# ____
# ____
# ____

# %% [markdown]
# ## 6) SVM para regressão
#
# Embora fizemos nossa apresentação do SVM como um classificador, também é possível utilizar este método para regressão!
#
# Todos os elementos do classificador SVM (margem, kernel, etc.) também são relevantes aqui.
#
# A ideia é bem simples: utilização de um kernel para que um modelo de **regressão linear seja treinado no espaço de features**. No espaço de inputs, este modelo é refletido como uma regressão não-linear (da mesma forma que, no caso de classificação, fronteiras de decisão lineares no espaço de features são refletidas como fronteiras não-lineares no espaçõ de input).
#
# A principal diferença é que o conceito de margem também está presente, de modo que **apenas alguns pontos efetivamente vão contriuir para a regressão**. Neste caso, são os pontos **dentro da margem** (região conhecida como $\epsilon-$tubo) que serão estes vetores de suporte. Ou seja, pontos que estão fora da margem não contribuem para a função de custo.
#
# <img src=https://www.saedsayad.com/images/SVR_5.png width=600>
#
# Uma comparação entre classificadores e regressores SVM:
#
# <img src=https://miro.medium.com/max/1100/1*XE9jt0r1yAW8LnliQ3mllQ.png width=600>

# %% [markdown]
# A classe de regressores SVM no sklearn é a [SVR](https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVR.html). Vamos vê-la em ação!

# %%
# Vamos usar um dataset que tenho target com valores contínuos para a regressão
df = pd.read_csv("../datasets/house_prices.csv")
# Carregar o dataset
X= df.drop(columns=['SalePrice', 'Id'])
y= df['SalePrice']
# DEfinir quem são as features e quem é o target

# particiona os dados em treino e teste
X_train, X_test, y_train,y_test = train_test_split(X, y, test_size=.2, random_state=42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     588 non-null    object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# criando a função
def pipe_pre_process_house_prices():
    df= pd.read_csv("../datasets/house_prices.csv")
    X= df.drop(columns=['SalePrice', 'Id'])
    y= df['SalePrice']

    # daqui para baixo a função é igual a de cima
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
    
    # ==========================================================
    pipe_features_num = Pipeline([("input_num", SimpleImputer(strategy='mean')), #substituir dados faltantes pela média
                                  ("std_scaler", StandardScaler())])            #padronização/normalização dos dados
    # Transformação das colunas numéricas
    features_num = X_train.select_dtypes(include=np.number).columns.tolist()

    # ==========================================================

    # transformação nas colunas categóricas
    pipe_feature_cat = Pipeline([("input_cat", SimpleImputer(strategy='constant', fill_value='unknown')),
                                 ("onehot", OneHotEncoder())])
    features_cat = X_train.select_dtypes(exclude=np.number).columns.tolist()
    # ==========================================================

    # aplicando a transformação nos dados de treino tanto nas colunas numéricas quanto nas colunas categóricas
    pre_processador = ColumnTransformer([("tranfr_num", pipe_features_num, features_num),
                                         ("transf_cat", pipe_feature_cat, features_cat)])
    
    return X_train, X_test, y_train, y_test, pre_processador

# %%
# são as métricas que usamos quando tem regressão!!!!
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
# função para avaliar o modelo
def metricas_regressao(estimator):
    # predições de treino
    y_train_pred = estimator.predict(X_train)
    print("\nMétricas de avaliação de treino")
    print(f"R2: { r2_score(y_train, y_train_pred):.2f}")
    print(f"MAE: { mean_absolute_error(y_train, y_train_pred):.2f}")
    print(f"RMSE: { np.sqrt(mean_squared_error(y_train, y_train_pred)):.2f}")
    
    # predições de teste
    y_pred_test = estimator.predict(X_test)
    
    print("\nMétricas de avaliação de teste")
    print(f"R2: { r2_score(y_test, y_pred_test):.2f}")
    print(f"MAE: { mean_absolute_error(y_test, y_pred_test):.2f}")
    print(f"RMSE: { np.sqrt(mean_squared_error(y_test, y_pred_test)):.2f}")

# %%
# carregar o SVM para regressão
from sklearn.svm import SVR

# %%
# chamando a função de preprocessamento
X_train, X_test, y_train, y_test, pre_processador = pipe_pre_process_house_prices()

pipe_svr = Pipeline([('pre_process', pre_processador),("svr", SVR())])

pipe_svr.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pre_process',
#                  ColumnTransformer(transformers=[('tranfr_num',
#                                                   Pipeline(steps=[('input_num',
#                                                                    SimpleImputer()),
#                                                                   ('std_scaler',
#                                                                    StandardScaler())]),
#                                                   ['MSSubClass', 'LotFrontage',
#                                                    'LotArea', 'OverallQual',
#                                                    'OverallCond', 'YearBuilt',
#                                                    'YearRemodAdd', 'MasVnrArea',
#                                                    'BsmtFinSF1', 'BsmtFinSF2',
#                                                    'BsmtUnfSF', 'TotalBsmtSF',
#                                                    '1stFlrSF', '2ndFlrSF',
#                                                    'LowQualFinSF...
#                                                    'LandContour', 'Utilities',
#                                                    'LotConfig', 'LandSlope',
#                                                    'Neighborhood', 'Condition1',
#                                                    'Condition2', 'BldgType',
#                                                    'HouseStyle', 'RoofStyle',
#                                                    'RoofMatl', 'Exterior1st',
#                                                    'Exterior2nd', 'MasVnrType',
#                                                    'ExterQual', 'ExterCond',
#                                                    'Foundation', 'BsmtQual',
#                                                    'BsmtCond', 'BsmtExposure',
#                                                    'BsmtFinType1',
#                                                    'BsmtFinType2', 'Heating',
#                                                    'HeatingQC', 'CentralAir',
#                                                    'Electrical', ...])])),
#                 ('svr', SVR())])

# %%
X_test["Condition2"].value_counts()
# Out:
# Condition2
# Norm     288
# Feedr      3
# RRNn       1
# Name: count, dtype: int64

# %%
# Avaliar o modelo
metricas_regressao(pipe_svr)
# Out:
# Métricas de avaliação de treino
# R2: -0.04427577967129093:.2f
# MAE: 54502.061804888006:.2f
# RMSE: 78921.70486135948:.2f
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula 2 - SVM.ipynb Cell 75 line 2
#       <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=0'>1</a> # Avaliar o modelo
# ----> <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> metricas_regressao(pipe_svr)
#
# /home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula 2 - SVM.ipynb Cell 75 line 1
#       <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=7'>8</a> print(f"RMSE: { np.sqrt(mean_squared_error(y_train, y_train_pred))}:.2f")
#      <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=9'>10</a> # predições de teste
# ---> <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=10'>11</a> y_pred_test = estimator.predict(X_test)
#      <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=12'>13</a> print("\nMétricas de avaliação de teste")
#      <a href='vscode-notebook-cell:/home/victor/Documents/1-DataScience/3-Aulas/1-Ada/ML2/Aula02/Aula%202%20-%20SVM.ipynb#Y135sZmlsZQ%3D%3D?line=13'>14</a> print(f"R2: { r2_score(y_test, y_pred_test)}:.2f")
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/pipeline.py:514, in Pipeline.predict(self, X, **predict_params)
#     512 Xt = X
#     513 for _, name, transform in self._iter(with_final=False):
# --> 514     Xt = transform.transform(Xt)
#     515 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py:827, in ColumnTransformer.transform(self, X)
#     822 else:
#     823     # ndarray was used for fitting or transforming, thus we only
#     824     # check that n_features_in_ is consistent
#     825     self._check_n_features(X, reset=False)
# --> 827 Xs = self._fit_transform(
#     828     X,
#     829     None,
#     830     _transform_one,
#     831     fitted=True,
#     832     column_as_strings=fit_dataframe_and_transform_dataframe,
#     833 )
#     834 self._validate_output(Xs)
#     836 if not Xs:
#     837     # All transformers are None
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/compose/_column_transformer.py:681, in ColumnTransformer._fit_transform(self, X, y, func, fitted, column_as_strings)
#     675 transformers = list(
#     676     self._iter(
#     677         fitted=fitted, replace_strings=True, column_as_strings=column_as_strings
#     678     )
#     679 )
#     680 try:
# --> 681     return Parallel(n_jobs=self.n_jobs)(
#     682         delayed(func)(
#     683             transformer=clone(trans) if not fitted else trans,
#     684             X=_safe_indexing(X, column, axis=1),
#     685             y=y,
#     686             weight=weight,
#     687             message_clsname="ColumnTransformer",
#     688             message=self._log_message(name, idx, len(transformers)),
#     689         )
#     690         for idx, (name, trans, column, weight) in enumerate(transformers, 1)
#     691     )
#     692 except ValueError as e:
#     693     if "Expected 2D array, got 1D array instead" in str(e):
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/pipeline.py:940, in _transform_one(transformer, X, y, weight, **fit_params)
#     939 def _transform_one(transformer, X, y, weight, **fit_params):
# --> 940     res = transformer.transform(X)
#     941     # if we have a weight for this transformer, multiply output
#     942     if weight is None:
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/pipeline.py:696, in Pipeline.transform(self, X)
#     694 Xt = X
#     695 for _, _, transform in self._iter():
# --> 696     Xt = transform.transform(Xt)
#     697 return Xt
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:1027, in OneHotEncoder.transform(self, X)
#    1022 # validation of X happens in _check_X called by _transform
#    1023 warn_on_unknown = self.drop is not None and self.handle_unknown in {
#    1024     "ignore",
#    1025     "infrequent_if_exist",
#    1026 }
# -> 1027 X_int, X_mask = self._transform(
#    1028     X,
#    1029     handle_unknown=self.handle_unknown,
#    1030     force_all_finite="allow-nan",
#    1031     warn_on_unknown=warn_on_unknown,
#    1032 )
#    1034 n_samples, n_features = X_int.shape
#    1036 if self._drop_idx_after_grouping is not None:
#
# File ~/Documents/1-DataScience/3-Aulas/1-Ada/ML2/venv/ml2/lib/python3.9/site-packages/sklearn/preprocessing/_encoders.py:200, in _BaseEncoder._transform(self, X, handle_unknown, force_all_finite, warn_on_unknown, ignore_category_indices)
#     195 if handle_unknown == "error":
#     196     msg = (
#     197         "Found unknown categories {0} in column {1}"
#     198         " during transform".format(diff, i)
#     199     )
# --> 200     raise ValueError(msg)
#     201 else:
#     202     if warn_on_unknown:
#
# ValueError: Found unknown categories ['Membran'] in column 14 during transform

# %% [markdown]
# Apareceu uma categoria nova nos dados de treino (que o modelo não conhecia - não sabe lidar)

# %%
for col in X_test.select_dtypes(exclude=np.number).columns:
    if "Membran" in X_test[col].unique().tolist():
        print(col)
# Out:
# RoofMatl

# %%
X_test.select_dtypes(exclude=np.number).columns.tolist().index("RoofMatl")
# Out:
# 14

# %%
X_train["RoofMatl"].unique()
# Out:
# array(['CompShg', 'WdShngl', 'WdShake', 'Metal', 'Tar&Grv', 'ClyTile',
#        'Roll'], dtype=object)

# %%
X_test["RoofMatl"].unique()
# Out:
# array(['CompShg', 'WdShake', 'WdShngl', 'Membran', 'Tar&Grv'],
#       dtype=object)

# %% [markdown]
# Corrigindo, então, com o `handle_unknown`:

# %%
# criando a função
def pipe_pre_process_house_prices():
    df= pd.read_csv("../datasets/house_prices.csv")
    X= df.drop(columns=['SalePrice', 'Id'])
    y= df['SalePrice']

    # daqui para baixo a função é igual a de cima
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42)
    
    # ==========================================================
    pipe_features_num = Pipeline([("input_num", SimpleImputer(strategy='mean')), #substituir dados faltantes pela média
                                  ("std_scaler", StandardScaler())])            #padronização/normalização dos dados
    # Transformação das colunas numéricas
    features_num = X_train.select_dtypes(include=np.number).columns.tolist()

    # ==========================================================

    # transformação nas colunas categóricas
    pipe_feature_cat = Pipeline([("input_cat", SimpleImputer(strategy='constant', fill_value='unknown')),
                                 ("onehot", OneHotEncoder(handle_unknown='ignore'))])
    features_cat = X_train.select_dtypes(exclude=np.number).columns.tolist()
    # ==========================================================

    # aplicando a transformação nos dados de treino tanto nas colunas numéricas quanto nas colunas categóricas
    pre_processador = ColumnTransformer([("tranfr_num", pipe_features_num, features_num),
                                         ("transf_cat", pipe_feature_cat, features_cat)])
    
    return X_train, X_test, y_train, y_test, pre_processador

# %%
# chamando a função de preprocessamento
X_train, X_test, y_train, y_test, pre_processador = pipe_pre_process_house_prices()

pipe_svr = Pipeline([('pre_process', pre_processador),("svr", SVR())])

pipe_svr.fit(X_train, y_train)

metricas_regressao(pipe_svr)
# Out:
# Métricas de avaliação de treino
# R2: -0.04
# MAE: 54502.06
# RMSE: 78921.70
#
# Métricas de avaliação de teste
# R2: -0.02
# MAE: 59515.83
# RMSE: 88626.09

# %% [markdown]
# Temos um alto underfitting!!!

# %% [markdown]
# Pra testar se a culpa é do estimador ou dos dados:

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test, pre_processador = pipe_pre_process_house_prices()

pipe_rf = Pipeline([('pre_process', pre_processador),("rf", RandomForestRegressor(random_state=42))])

pipe_rf.fit(X_train, y_train)
metricas_regressao(pipe_rf)
# Out:
# Métricas de avaliação de treino
# R2: 0.98
# MAE: 6586.81
# RMSE: 11231.32
#
# Métricas de avaliação de teste
# R2: 0.89
# MAE: 17490.18
# RMSE: 28926.46

# %%
# pra casa: pq está tão ruim, e como podemos melhorar? (além dos hiperparâmetros)

# %%
# %store X_train
